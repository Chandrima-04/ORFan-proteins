# %%
import pandas as pd
import re
import itertools
import matplotlib_venn
import numpy as np

# %% [markdown]
# # 1. Load blast hits , hmmer hits for MetaHIT and cluster stats

# %%
#Load blast best hits
filt_blast_hits = pd.read_csv("1_out/filtered_blast_all_hits.csv")
print(filt_blast_hits.shape)
#Load hmmer best hits
filt_hmmer_hits = pd.read_csv("1_out/filtered_hmmer_all_hits.csv")
print(filt_hmmer_hits.shape)

all_filt_hits = pd.concat([filt_blast_hits,filt_hmmer_hits],axis=0)
#Load cluster stats
clusters = pd.read_csv("1_out/cluster_stats.csv")
clusters["sample_origin"] = clusters["sample_origin"].apply(lambda x:x.replace(",",";"))
# Out:
# (3400, 23)
# (1882, 22)

# %%
#Get MetaHIT 2014 IGC hits
metahit_2014 = all_filt_hits[all_filt_hits.db.apply(lambda x: ("metahit" in x) and ("2014" in x))]
print(metahit_2014.shape)
metahit_2014.head()
# Out:
# (3389, 37)
#       ali_len  best_dmn_bias  best_dmn_bitscore  best_dmn_e_value  bias  \
# 1566    270.0            NaN                NaN               NaN   NaN
# 1567    270.0            NaN                NaN               NaN   NaN
# 1568    263.0            NaN                NaN               NaN   NaN
# 1569    274.0            NaN                NaN               NaN   NaN
# 1570    259.0            NaN                NaN               NaN   NaN
#
#       bitscore cluster                db  dne_clu  dne_dom   ...    \
# 1566     431.0    1073  metahit_2014_cds      NaN      NaN   ...
# 1567     420.0    1073  metahit_2014_cds      NaN      NaN   ...
# 1568     254.0    1073  metahit_2014_cds      NaN      NaN   ...
# 1569     409.0    1073  metahit_2014_cds      NaN      NaN   ...
# 1570     401.0    1073  metahit_2014_cds      NaN      NaN   ...
#
#                                           s_description  s_end  s_gi  s_len  \
# 1566  MH0019_GL0030364  [gene]  locus=scaffold39654_...   35.0   0.0  549.0
# 1567  765620695-stool1_revised_scaffold38964_2_gene1...   35.0   0.0  546.0
# 1568  MH0048_GL0036718  [gene]  locus=scaffold33886_...   35.0   0.0  537.0
# 1569  V1.CD14-0_GL0044222  [gene]  locus=scaffold182...   45.0   0.0  567.0
# 1570  V1.CD6-0-PT_GL0032215  [gene]  locus=scaffold1...   42.0   0.0  564.0
#
#       s_names  s_scinames  s_start  s_taxids  \
# 1566      NaN         NaN    304.0       NaN
# 1567      NaN         NaN    304.0       NaN
# 1568      NaN         NaN    294.0       NaN
# 1569      NaN         NaN    318.0       NaN
# 1570      NaN         NaN    300.0       NaN
#
#                                              subject_id    tool
# 1566                                   MH0019_GL0030364  blastn
# 1567  765620695-stool1_revised_scaffold38964_2_gene1...  blastn
# 1568                                   MH0048_GL0036718  blastn
# 1569                                V1.CD14-0_GL0044222  blastn
# 1570                              V1.CD6-0-PT_GL0032215  blastn
#
# [5 rows x 37 columns]

# %%
#Get MetaHIT 2010 hits
metahit_2010 = all_filt_hits[all_filt_hits.db.apply(lambda x: ("metahit" in x) and ("2014" not in x))]
print(metahit_2010.shape)
metahit_2010.head()
# Out:
# (1206, 37)
#      ali_len  best_dmn_bias  best_dmn_bitscore  best_dmn_e_value  bias  \
# 536    270.0            NaN                NaN               NaN   NaN
# 537    259.0            NaN                NaN               NaN   NaN
# 538    270.0            NaN                NaN               NaN   NaN
# 539    273.0            NaN                NaN               NaN   NaN
# 540    283.0            NaN                NaN               NaN   NaN
#
#      bitscore cluster           db  dne_clu  dne_dom   ...    \
# 536     431.0    1073  metahit_cds      NaN      NaN   ...
# 537     412.0    1073  metahit_cds      NaN      NaN   ...
# 538     243.0    1073  metahit_cds      NaN      NaN   ...
# 539     444.0    1073  metahit_cds      NaN      NaN   ...
# 540     272.0    1073  metahit_cds      NaN      NaN   ...
#
#                                          s_description  s_end  s_gi  s_len  \
# 536  GL0053633_MH0019_[Complete]_[mRNA]_locus=scaff...   35.0   0.0  549.0
# 537  GL0080651_MH0011_[Complete]_[mRNA]_locus=scaff...   45.0   0.0  555.0
# 538  GL0144339_V1_[Complete]_[mRNA]_locus=scaffold3...   51.0   0.0  561.0
# 539  GL0080651_MH0011_[Complete]_[mRNA]_locus=scaff...   31.0   0.0  555.0
# 540  GL0144339_V1_[Complete]_[mRNA]_locus=scaffold3...   38.0   0.0  561.0
#
#      s_names  s_scinames  s_start  s_taxids  \
# 536      NaN         NaN    304.0       NaN
# 537      NaN         NaN    303.0       NaN
# 538      NaN         NaN    315.0       NaN
# 539      NaN         NaN    303.0       NaN
# 540      NaN         NaN    315.0       NaN
#
#                                             subject_id    tool
# 536  GL0053633_MH0019_[Complete]_[mRNA]_locus=scaff...  blastn
# 537  GL0080651_MH0011_[Complete]_[mRNA]_locus=scaff...  blastn
# 538  GL0144339_V1_[Complete]_[mRNA]_locus=scaffold3...  blastn
# 539  GL0080651_MH0011_[Complete]_[mRNA]_locus=scaff...  blastn
# 540  GL0144339_V1_[Complete]_[mRNA]_locus=scaffold3...  blastn
#
# [5 rows x 37 columns]

# %%
print(clusters.shape)
clusters.head()
# Out:
# (32, 23)
#   Cluster  # nr seqs  # raw seqs   Score  log RNAcode score          P  \
# 0    1217          6           6  41.974               1.62  7.704e–10
# 1    339b          7          11  33.153               1.52  1.069e–06
# 2    211b          7          22  42.949               1.63  3.364e–14
# 3     562          7           9  39.417               1.60  4.592e–07
# 4    297a          5          14  26.891               1.43      0.001
#
#    ORF length (aa)  log ORF length complexity   min      ...       min.1  \
# 0               91            1.96         hi  3.79      ...          38
# 1              110            2.04         hi  3.89      ...          63
# 2               80            1.90         hi  3.72      ...          31
# 3               61            1.79         hi  3.78      ...          29
# 4              106            2.03         hi  3.90      ...          59
#
#    avg.1  max.1  # seqs with max length  composite score  \
# 0  73.67     87                       2             7.57
# 1  79.14    106                       2             7.52
# 2  62.00     73                       2             7.49
# 3  49.57     59                       8             7.39
# 4  96.60    106                       8             7.38
#
#                                        DNA alignment  \
# 0  <a href="all_nt_aln/cluster1217_DNA.aln.txt">D...
# 1  <a href="all_nt_aln/cluster339b_DNA.aln.txt">D...
# 2  <a href="all_nt_aln/cluster211b_DNA.aln.txt">D...
# 3  <a href="all_nt_aln/cluster562_DNA.aln.txt">DN...
# 4  <a href="all_nt_aln/cluster297a_DNA.aln.txt">D...
#
#                                    protein alignment  \
# 0  <a href="all_aa_aln/cluster1217_AA.aln.txt">AA...
# 1  <a href="all_aa_aln/cluster339b_AA.aln.txt">AA...
# 2  <a href="all_aa_aln/cluster211b_AA.aln.txt">AA...
# 3  <a href="all_aa_aln/cluster562_AA.aln.txt">AA</a>
# 4  <a href="all_aa_aln/cluster297a_AA.aln.txt">AA...
#
#                                       RNAcode figure cluster_id sample_origin
# 0  <a href="rnacode_all/cluster1217_eps/hss-0.eps...       1217         feces
# 1  <a href="rnacode_all/cluster339b_eps/hss-0.eps...       339b         feces
# 2  <a href="rnacode_all/cluster211b_eps/hss-0.eps...       211b         feces
# 3  <a href="rnacode_all/cluster562_eps/hss-0.eps"...        562     CSF;serum
# 4  <a href="rnacode_all/cluster297a_eps/hss-0.eps...       297a         feces
#
# [5 rows x 23 columns]

# %% [markdown]
# # Load Metahit  annotations

# %%
metahit_2014_cols = ["gene_id","gene_name","gene_length","gene_completness",
                     "cohort_origin","phylum","genus","kegg","eggNOG",
                    "sample_freq","individual_freq","kegg_categories","eggnog_fx_categories","cohort_assembled"]

metahit_2014_annot = pd.read_csv("~/resources/IGC.annotation_OF.summary",sep="\t",header=None,names=metahit_2014_cols)

print(metahit_2014_annot.shape)
metahit_2014_annot.head()
# Out:
# (9879896, 14)
#    gene_id           gene_name  gene_length gene_completness cohort_origin  \
# 0        1    T2D-6A_GL0083352        88230         Complete           CHN
# 1        2  V1.UC4-5_GL0154511        88086         Complete           EUR
# 2        3    MH0198_GL0136826        67464      Lack 5'-end           EUR
# 3        4   V1.FI28_GL0106390        45267         Complete           EUR
# 4        5    MH0318_GL0144550        42243         Complete           EUR
#
#     phylum    genus    kegg    eggNOG  sample_freq  individual_freq  \
# 0  unknown  unknown  K01824   COG5184     0.224152         0.236449
# 1  unknown  unknown  K01824   COG5184     0.352802         0.351402
# 2  unknown  unknown  K01824   COG5184     0.281768         0.293458
# 3  unknown  unknown  K03924  NOG12793     0.278611         0.267290
# 4  unknown  unknown  K13730   COG4886     0.001579         0.001869
#
#        kegg_categories                               eggnog_fx_categories  \
# 0     Lipid Metabolism  Cell cycle control, cell division, chromosome ...
# 1     Lipid Metabolism  Cell cycle control, cell division, chromosome ...
# 2     Lipid Metabolism  Cell cycle control, cell division, chromosome ...
# 3           Metabolism                                   Function unknown
# 4  Infectious Diseases                                   Function unknown
#
#   cohort_assembled
# 0      EUR;CHN;USA
# 1      EUR;CHN;USA
# 2          EUR;CHN
# 3          EUR;USA
# 4              EUR

# %% [markdown]
# # 3. Annotate hits with metadata

# %%
#MetaHIT 2014
metahit_2014_df = pd.merge(metahit_2014, metahit_2014_annot, left_on="subject_id", right_on="gene_name",how="left")
print(metahit_2014_df.shape)
metahit_2014_df.head()
# Out:
# (3389, 51)
#    ali_len  best_dmn_bias  best_dmn_bitscore  best_dmn_e_value  bias  \
# 0    270.0            NaN                NaN               NaN   NaN
# 1    270.0            NaN                NaN               NaN   NaN
# 2    263.0            NaN                NaN               NaN   NaN
# 3    274.0            NaN                NaN               NaN   NaN
# 4    259.0            NaN                NaN               NaN   NaN
#
#    bitscore cluster                db  dne_clu  dne_dom        ...         \
# 0     431.0    1073  metahit_2014_cds      NaN      NaN        ...
# 1     420.0    1073  metahit_2014_cds      NaN      NaN        ...
# 2     254.0    1073  metahit_2014_cds      NaN      NaN        ...
# 3     409.0    1073  metahit_2014_cds      NaN      NaN        ...
# 4     401.0    1073  metahit_2014_cds      NaN      NaN        ...
#
#    cohort_origin   phylum    genus     kegg   eggNOG  sample_freq  \
# 0            EUR  unknown  unknown  unknown  unknown     0.041831
# 1            USA  unknown  unknown  unknown  unknown     0.014996
# 2            EUR  unknown  unknown  unknown  unknown     0.116811
# 3            EUR  unknown  unknown  unknown  unknown     0.014996
# 4            EUR  unknown  unknown  unknown  unknown     0.021310
#
#    individual_freq  kegg_categories  eggnog_fx_categories  cohort_assembled
# 0         0.045794          unknown               unknown       EUR;CHN;USA
# 1         0.015888          unknown               unknown               USA
# 2         0.111215          unknown               unknown               EUR
# 3         0.017757          unknown               unknown       EUR;CHN;USA
# 4         0.024299          unknown               unknown               EUR
#
# [5 rows x 51 columns]

# %% [markdown]
# # MetaHIT 2014
#
#
#
# ## a. Tax annotation
#
# Apparently there is no tax annotation for the hits we have in MetaHIT :D

# %%
metahit_2014_df.shape
print(metahit_2014_df[ metahit_2014_df.phylum != "unknown" ].shape)
print(metahit_2014_df[ metahit_2014_df.genus != "unknown" ].shape)
# Out:
# (0, 51)
# (0, 51)

# %% [markdown]
# ## b. KEGG

# %%
metahit_2014_df[metahit_2014_df.kegg != "unknown"][["cluster","tool","db","kegg","kegg_categories"]].drop_duplicates()
# Out:
#      cluster       tool                db    kegg         kegg_categories
# 619      348     blastn  metahit_2014_cds  K02314  Replication and Repair
# 1504     348     blastp  metahit_2014_pep  K02314  Replication and Repair
# 2897     348  hmmsearch  metahit_2014_pep  K02314  Replication and Repair
# 3234     532  hmmsearch  metahit_2014_pep  K06915    Poorly Characterized

# %% [markdown]
# ## c. eggNOG

# %%
metahit_2014_df[metahit_2014_df.eggNOG != "unknown"][["cluster","tool","db","eggNOG","eggnog_fx_categories"]].drop_duplicates()
# Out:
#      cluster       tool                db     eggNOG  \
# 619      348     blastn  metahit_2014_cds    COG0305
# 1504     348     blastp  metahit_2014_pep    COG0305
# 1882    1085  hmmsearch  metahit_2014_pep  NOG269643
# 2897     348  hmmsearch  metahit_2014_pep    COG0305
# 3234     532  hmmsearch  metahit_2014_pep    COG0433
#
#                        eggnog_fx_categories
# 619   Replication, recombination and repair
# 1504  Replication, recombination and repair
# 1882                                unknown
# 2897  Replication, recombination and repair
# 3234       General function prediction only

# %% [markdown]
# ## d. Individual and sample frequency in the MetaHIT samples

# %%
gb = metahit_2014_df[["cluster","individual_freq"]].groupby("cluster")
max_individual_freq = pd.DataFrame([ df.ix[ df.individual_freq.idxmax() ] for _,df in gb ] )

gb = metahit_2014_df[["cluster","sample_freq"]].groupby("cluster")
max_sample_freq = pd.DataFrame([ df.ix[ df.sample_freq.idxmax() ] for _,df in gb ] )

pd.merge(max_individual_freq,max_sample_freq,on="cluster",how="outer")
# Out:
#    cluster  individual_freq  sample_freq
# 0     1073         0.295327     0.298343
# 1     1085         0.004673     0.004736
# 2     113b         0.029907     0.025257
# 3     1217         0.228972     0.220205
# 4     179a         0.024299     0.025257
# 5     179b         0.024299     0.025257
# 6     182a         0.027103     0.026835
# 7     182b         0.027103     0.026835
# 8     211a         0.024299     0.023678
# 9     211b         0.024299     0.023678
# 10    241a         0.024299     0.023678
# 11    241b         0.034579     0.033938
# 12     258         0.035514     0.037885
# 13    297a         0.043925     0.052092
# 14    297b         0.043925     0.052092
# 15    321b         0.018692     0.022099
# 16    339b         0.019626     0.022099
# 17     348         0.210280     0.217048
# 18    375a         0.024299     0.025257
# 19    406b         0.168224     0.161800
# 20     502         0.024299     0.023678
# 21     532         0.121495     0.127072
# 22     589         0.017757     0.018942
# 23    612a         0.252336     0.257301
# 24    787b         0.044860     0.056038
